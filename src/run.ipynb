# %%
import read_data

# %%
read_data.read_data([0])
# Out:
# 0
# {'A1': [{'datetime': datetime.datetime(2017, 7, 3, 8, 49, 49, 799000),
#    'price': 4765000,
#    'highp': 4800000,
#    'lowp': 4700000,
#    'bidp': 4760000,
#    'bidv': 336,
#    'askp': 4765000,
#    'askv': 57,
#    'id': 'A1'},
#   {'datetime': datetime.datetime(2017, 7, 3, 8, 59, 49, 891000),
#    'price': 4765000,
#    'highp': 4800000,
#    'lowp': 4700000,
#    'bidp': 4760000,
#    'bidv': 336,
#    'askp': 4765000,
#    'askv': 56,
#    'id': 'A1'},
#   {'datetime': datetime.datetime(2017, 7, 3, 8, 59, 50, 387000),
#    'price': 4775000,
#    'highp': 4800000,
#    'lowp': 4700000,
#    'bidp': 4770000,
#    'bidv': 946,
#    'askp': 4775000,
#    'askv': 1467,
#    'id': 'A1'},
#   {'datetime': datetime.datetime(2017, 7, 3, 8, 59, 50, 886000),
#    'price': 4770000,
#    'highp': 4800000,
#    'lowp': 4700000,
#    'bidp': 4770000,
#    'bidv': 743,
#    'askp': 4775000,
#    'askv': 639,
#    'id': 'A1'},
# ...
